# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The data for regression does not match for the RF and RNN.
#
# It appears to be a problem with the data on the RF side.

# %%
survey = 'PanStarrs'
path_rf = '../../../../../../BRF_baseline/experiments/regression/{}/data/turbofats_test_T_eff.parquet'.format(survey)
df_rf = pd.read_parquet(path_rf)

# %%
df_rf
# Out:
#                          Class      T_eff  Psi_CS_1  Psi_eta_1  Psi_CS_2  \
# oid
# 90752870729198448          RRC  6033.0000  0.401608   0.709838  0.230879
# 111850650934828506         RRC  6731.0000  0.377084   0.384276  0.226727
# 115542702349595209         RRC  5990.3335  0.430317   0.857329  0.383393
# 74652707998828066         RRAB  4777.0000  0.382083   0.540769  0.447294
# 108932907287826790     MIRA_SR  3850.7400  0.315640   2.589868  0.308807
# ...                        ...        ...       ...        ...       ...
# 93772523605923026         RRAB  4437.1700  0.485355   0.660684  0.398012
# 128132569795921034  DSCT_SXPHE  7845.0000  0.347326   0.827093  0.378618
# 98022186269379486         RRAB  6536.6470  0.383527   1.197595  0.366214
# 137421240249180848         RRC  7529.1050  0.443697   0.744419  0.388656
# 75992789801039960         RRAB  4973.3335  0.397018   1.216329  0.440511
#
#                     Psi_eta_2  Psi_CS_3  Psi_eta_3  Psi_CS_4  Psi_eta_4  ...  \
# ...

# %%
test = pd.read_parquet('../../../../../../BRF_baseline/data/clean/PanStarrs_CleanTurboFATS.parquet')
test.head()
# Out:
#                      Psi_CS_1   Psi_eta_1    Psi_CS_2   Psi_eta_2    Psi_CS_3  \
# oid
# 70661397047985366 -999.000000 -999.000000 -999.000000 -999.000000    0.247837
# 70671446769613236    0.431710    1.761718    0.443407    0.510001    0.355551
# 70851191538836909    0.467830    0.856626    0.471394    2.267316 -999.000000
# 70861310212196391    0.497449    1.549287    0.485376    1.982506    0.361655
# 70881182911602481    0.399848    1.605161    0.471396    2.265647 -999.000000
#
#                     Psi_eta_3    Psi_CS_4   Psi_eta_4    Psi_CS_5   Psi_eta_5  \
# oid
# 70661397047985366    1.100784    0.416667    1.237065    0.406180    2.745741
# 70671446769613236    1.989453 -999.000000 -999.000000    0.392958    4.033122
# 70851191538836909 -999.000000 -999.000000 -999.000000    0.483188    2.132719
# 70861310212196391    0.932822    0.367301    2.524284    0.384083    1.468672
# 70881182911602481 -999.000000 -999.000000 -999.000000 -999.000000 -999.000000
#
# ...

# %%
path_rnn1 = '../01_CreateFolds/{}/Folds/test.csv'.format(survey)

df_rnn = pd.read_csv(path_rnn1).set_index('ID')
# df_rnn2 = pd.read_csv(path_rnn2)
# df_rnn = pd.concat([df_rnn1, df_rnn2], axis=0)
df_rnn.head()
# Out:
#                                                                  Path  \
# ID
# 90752870729198448   /home/iebecker/Desktop/iebecker_stuff/Disks/Da...
# 111850650934828506  /home/iebecker/Desktop/iebecker_stuff/Disks/Da...
# 115542702349595209  /home/iebecker/Desktop/iebecker_stuff/Disks/Da...
# 83502493453954487   /home/iebecker/Desktop/iebecker_stuff/Disks/Da...
# 74652707998828066   /home/iebecker/Desktop/iebecker_stuff/Disks/Da...
#
#                          Class   N  N_g  N_r  N_i  N_z  N_y      T_eff  \
# ID
# 90752870729198448          RRC  63   15    9    5   19   15  6033.0000
# 111850650934828506         RRC  77   15   14   20    9   19  6731.0000
# 115542702349595209         RRC  60   10   10   15   13   12  5990.3335
# 83502493453954487   DSCT_SXPHE  65   16   11   12   14   12    -1.0000
# 74652707998828066         RRAB  61   22    7   12   11    9  4777.0000
#
#                       e_T_eff  ...  E_Rad    logg  e_logg  E_logg  Mass  \
# ...

# %% [markdown]
# Find the df_rnn IDs and then match them to the RF data

# %%
df = pd.merge(left=df_rf, right=df_rnn, left_index=True, right_index=True)
df.shape
# Out:
# (3652, 286)

# %%
pd.merge(left=test, right=df_rnn, left_index=True, right_index=True)
# Out:
#                     Psi_CS_1  Psi_eta_1  Psi_CS_2  Psi_eta_2  Psi_CS_3  \
# 71652365171781460   0.475093   1.260898  0.389227   1.004027  0.415885
# 71791387664171476   0.440909   1.511515  0.359810   1.378447  0.432183
# 72042374098681833   0.447530   0.936045  0.473556   0.957527  0.278113
# 72092721558247345   0.458064   1.157786  0.358229   2.119613  0.440676
# 72302474142159314   0.321486   1.760131  0.384114   0.871588  0.467977
# ...                      ...        ...       ...        ...       ...
# 207290265958715454  0.285994   1.332223  0.442351   0.645434  0.326697
# 207940148537257647  0.425975   2.073734  0.293203   1.087947  0.243908
# 208780849770754202  0.281224   2.323823  0.420284   0.834617  0.346799
# 210770444409709661  0.399262   1.579385  0.454063   1.230448  0.299027
# 214140269281741984  0.376458   1.588052  0.402388   1.174029  0.445318
#
#                     Psi_eta_3  Psi_CS_4  Psi_eta_4  Psi_CS_5  Psi_eta_5  ...  \
# ...
