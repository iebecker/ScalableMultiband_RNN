# %%
import sys
import os
from glob import glob
from itertools import combinations

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


# Avoids warnings
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"
import tensorflow as tf

import ScalableLib.classifier.Multiband as multiband
from ScalableLib.classifier.CustomLayers import SauceLayer, LastRelevantLayer, ApplyMask, MeanMagLayer, MeanColorLayer
# Out:
# 2024-12-08 19:47:05.523026: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-08 19:47:05.523057: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-08 19:47:05.524099: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-08 19:47:06.451188: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# import pandas as pd
# import numpy as np
# import sys
# import matplotlib.pyplot as plt
# import tensorflow as tf
# import os
# from glob import glob
# from itertools import combinations
# # sys.path.append('/home/ibecker/Dropbox/MyPythonClasses/FinalClass/')

# # import Classifier.Model_53.Multiband_53 as multiband
# # from Classifier.Model_53.CustomLayers import SauceLayer, LastRelevantLayer, ApplyMask, MeanMagLayer, MeanColorLayer

# %% [markdown]
# the filtering of the times must be done in the spine, not in each band. Spit all the times then slect the best one.

# %%
# To see if the system recognises the GPU
device = 0
devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.set_visible_devices(devices[device], 'GPU')
tf.config.experimental.set_memory_growth(device=devices[device], enable=True)

device_name = tf.config.experimental.get_device_details(devices[device])['device_name']
print("Using {}".format(device_name))
# Out:
# Using NVIDIA GeForce RTX 3080

# %% [markdown]
# Find the different folds and train a model using the stored data.

# %%
survey = 'Gaia'
path = os.path.join('../../../CV_c/02_CreateRecords/', survey, 'Folds/Fold_*',)
folds = glob(path)
folds.sort()
folds
# Out:
# ['../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_1',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_2',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_3',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_4',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_5',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_6',
#  '../../../CV_c/02_CreateRecords/Gaia/Folds/Fold_7']

# %% [markdown]
# Create folder results

# %%
if not os.path.exists('./Results'):
    os.mkdir('./Results')

# %% [markdown]
# Define the arguments for all the models.

# %%
train_args = {
            'hidden_size_bands':[128, 128, 128],
            'hidden_size_central':[128, 128],
            'fc_layers_bands':[128,128,128],
            'fc_layers_central':[128,128,128], # Neurons of each layer
            'regression_size':[128, 128],#each element is a layer with that size.
            'buffer_size':10000,
            'epochs':1000,
            'num_threads':7,
            'batch_size':512,
            'dropout':0.40,
            'lr':[[1e-3]*2, 0.5e-3], # [[band1, band2], central]
            'val_steps':50,
            'max_to_keep':0, # Not Used 
            'steps_wait':500, 
            'use_class_weights':False,# Not Used
            'mode' : 'classifier'
            }
loss_weights = {'Class':1.0}

callbacks_args = {'patience': 20,
                  'mode':'max',
                  'restore_best_weights':True,
                  'min_delta': 0.001
                 }
train_args_specific={
                    'phys_params': [],
                    'use_output_bands' : True,  # Working
                    'use_output_central' : False, # Not used
                    'use_common_layers' : False, # NOT Working
                    'bidirectional_central' : False,# Working
                    'bidirectional_band' : False,# Not Working
                    'layer_norm_params' : None, # Used to normalyze common layers
                    'use_gated_common' : False, # Working
                    'l1':0.0,
                    'l2':0.0,   
                    'N_skip' : 8, # Cannot be greater than the number of timesteps
                    'use_raw_input_central': True,
                    'train_steps_central' : 2,
                    'print_report' : True,
                    'loss_weights_central' : loss_weights,
                    'callbacks_args':callbacks_args
                    }

# %% [markdown]
# Create the scapulars and coonect them at the end

# %%
def compute_FinalMeanMags(output, length):

    batch_size = tf.shape(output)[0]
    indices = tf.stack([tf.range(0, batch_size), length], axis=1)
    final_MeanMags = tf.gather_nd(output, indices)
    return final_MeanMags

def compute_ColorMatrix(n_bands):
    """ Obtains the matrix to compute the colors (magnitude differences)
    between all the bands. In the 2-band scenario it reduces to [[1, -1]].
    """
    NN = n_bands
    # Compute all possible combinations
    combs = set(combinations(np.arange(NN), 2))
    combs = [list(i) for i in combs]
    combs = tf.constant(combs)

    # Compute the index of the first elements
    v1 = tf.reshape(combs[:, 0], [-1, 1])
    v1b = tf.reshape(tf.range(tf.shape(combs)[0]), [-1, 1])
    v1 = tf.concat([v1b, v1], axis=1)
    # Compute the index of the second elements
    v2 = tf.reshape(combs[:, 1], [-1, 1])
    v1b = tf.reshape(tf.range(tf.shape(combs)[0]), [-1, 1])
    v2 = tf.concat([v1b, v2], axis=1)

    # Concatenate and cast to int64
    indices = tf.concat([v1, v2], axis=0)
    indices = tf.cast(indices, tf.int64)

    # First part are the first elements
    u1 = tf.ones(tf.shape(v1)[0])
    # Second part are the subtracted elements
    u2 = -tf.ones(tf.shape(v1)[0])
    updates = tf.concat([u1, u2], axis=0)

    # Compute the shape #combinations x bands
    shape = tf.stack([tf.shape(v1)[0], NN], axis=0)
    shape = tf.cast(shape, tf.int64)

    # Obtain the matrix
    diff_matrix = tf.scatter_nd(indices, updates, shape)

    # Transpose it to perform MatMult afterwards
    diff_matrix = tf.transpose(diff_matrix)
    return diff_matrix

# %%
class LastRelevantLayer_mod(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(LastRelevantLayer_mod, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, output, length):
        '''Get the last relevant output from the network'''
        batch_size = tf.shape(output)[0]
        max_length = tf.shape(output)[1]
        out_size = tf.shape(output)[2]

        index = tf.range(0, batch_size) * max_length + (length - 1)
        flat = tf.reshape(output, [-1, out_size])
        relevant = tf.gather(flat, index)
        
        relevant = tf.reshape(relevant, [batch_size, output.shape[2]])
        return relevant
 

def creat_split_models():
    tf.keras.backend.clear_session()
    inputs = {}
    keys =new.dataset_test.element_spec[0].keys()
    for key in keys:
        inputs[key] = tf.keras.layers.Input(shape=new.dataset_test.element_spec[0][key].shape[1:],
                                            dtype=new.dataset_test.element_spec[0][key].dtype,
                                            name=key
                                            )
    out = {}
    sauces = []
    Mean_Mags = []
    
    for model in range(len(new.models)):
        # Get the single band outputs
        new.models[model].trainable = True
        out[model] = new.models[model].layers[2].output
        slice_model = tf.keras.Model(inputs=new.models[model].inputs, outputs=out[model])

        out_model = slice_model(inputs)
        # Get the last relevant per band per output
        lasts = []
        for i in range(len(out_model)):
            last_relevant = LastRelevantLayer_mod()(out_model[i], inputs['N_'+str(model)])
            lasts.append(last_relevant)
        # Create a Sauce layer per band
        size = len(lasts)
        sauce = SauceLayer(size, name='Sauce_'+str(model))(lasts)
        sauces.append(sauce)

        # Compute the mean mags
        MeanMag = MeanMagLayer(new.w,
                               name='MeanMag_'+str(model)
                               )
        mean_mags = MeanMag(inputs['input_LC_'+str(model)],
                            inputs['N_'+str(model)],
                            inputs['M0_'+str(model)],
                            )        
        Mean_Mags.append(mean_mags)

    final_MeanMags = [compute_FinalMeanMags(Mean_Mags[i], inputs['N_'+str(i)]) for i in range(new.n_bands)]
    final_MeanMags = tf.stack(final_MeanMags, axis=1)
    color_matrix = compute_ColorMatrix(new.n_bands)
    colors = tf.matmul(final_MeanMags, color_matrix)
        
    # Stack the outputs
    embedding = tf.keras.layers.Concatenate(axis=1, name='Concat_Sauces')(sauces)

    # Stack the colors
    embedding =  tf.keras.layers.Concatenate(axis=-1, name='Concat_Colors')([embedding, colors])
    # Add dense layers with dropout
    sizes = train_args['fc_layers_central']
    proyections = embedding
    for b in range(len(sizes)):
        proyections = tf.keras.layers.Dense(sizes[b],
                                        activation=None,
                                        use_bias=False,
                                        )(proyections)
        proyections = tf.keras.layers.BatchNormalization()(proyections, training=True)
        proyections = tf.keras.activations.relu(proyections)

        proyections = tf.keras.layers.Dropout(new.dropout)(proyections)

    predictions_prob = tf.keras.layers.Dense(new.num_classes,
                                             activation='softmax',
                                             use_bias=True,
                                             name='Predictions',
    #                                          bias_initializer=tf.constant_initializer(1.0/self.numpy_weights),
                                             )(proyections)
    outputs = {
            'Class': predictions_prob,

            }
    model = tf.keras.Model(inputs = inputs, outputs=outputs)
    optimizer = new.optimizers[0]
    loss = 'categorical_crossentropy'
    model.compile(optimizer=optimizer, loss=loss, metrics='accuracy')

    return model

# %%
sauces = []
for fold in folds:
    tf.keras.backend.clear_session()
    # Set the fold path
    base_dir = fold+'/'
    
    # Set the save path for this fold. Create folder if needed
    path_results_fold = fold.replace(f'../../../CV_c/02_CreateRecords/{survey}', '.').replace('/Folds/', '/Results/')

    if not os.path.exists(path_results_fold):
        os.mkdir(path_results_fold)    

    train_args_specific['save_dir'] = path_results_fold
    train_args_specific['metadata_pre_path'] = os.path.join(fold, 'metadata_preprocess.json')
    train_args_specific['path_scalers'] =  os.path.join(fold,'scalers.pkl')
    # Define the train args
    train_args = {**train_args, **train_args_specific}

    train_files = os.path.join(fold, 'train/*.tfrecord')
    val_files = os.path.join(fold, 'val/*.tfrecord')
    test_files = os.path.join(fold, 'test/*.tfrecord')
    
    new = multiband.Network()    
    new.train(train_args, train_files, val_files, test_files)
    model = creat_split_models()
    
    es = tf.keras.callbacks.EarlyStopping(**callbacks_args)
    model.fit(new.dataset_train, validation_data=new.dataset_val, epochs=200,callbacks = [es] )
    
    # Store the alpha coefficients per fold
    sauces_ = {i.name:i for i in model.layers if 'Sauce_' in i.name}
    scales = {key:tf.nn.softmax(sauces_[key].scale).numpy() for key in sauces_.keys()}
    sauces.append(scales)
    # Test
    dfs = []
    for batch in new.dataset_test:
        prediction = model(batch[0])
        y_pred = prediction['Class'].numpy().argmax(axis=1)
        y_pred = [new.trans[i] for i in y_pred]
        ID = batch[0]['ID'].numpy()

        y_true = batch[1]['Class'].numpy().argmax(axis=1)
        y_true = [new.trans[i] for i in y_true]

        df = pd.DataFrame(np.array([ID, y_pred, y_true]).transpose(), columns=['ID', 'Class', 'Pred'])
        df.ID = df.ID.str.decode('UTF-8')
        dfs.append(df)
    dfs = pd.concat(dfs, axis=0)
    dfs.to_csv(path_results_fold+'/Classification_test.dat', index=False, index_label=False)
    
pd.DataFrame(sauces).to_csv(path_results_fold+'/sauces.dat', index=False, index_label=False)
# Out:
# ./Results/Fold_1/Models/20241208-1948
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1
200
# 145/145 [==============================] - 7s 51ms/step - loss: 0.4163 - accuracy: 0.8405 - val_loss: 0.3616 - val_accuracy: 0.8571
# Epoch 8/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.4092 - accuracy: 0.8458 - val_loss: 0.3590 - val_accuracy: 0.8606
# Epoch 9/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3977 - accuracy: 0.8506 - val_loss: 0.3506 - val_accuracy: 0.8657
# Epoch 10/200
# 145/145 [==============================] - 7s 51ms/step - loss: 0.3868 - accuracy: 0.8523 - val_loss: 0.3447 - val_accuracy: 0.8683
# Epoch 11/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3778 - accuracy: 0.8568 - val_loss: 0.3428 - val_accuracy: 0.8695
# Epoch 12/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3720 - accuracy: 0.8586 - val_loss: 0.3393 - val_accuracy: 0.8705
# Epoch 13/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3629 - accuracy: 0.8618 - val_loss: 0.3369 - val_accuracy: 0.8704
# Epoch 14/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3585 - accuracy: 0.8635 - val_loss: 0.3296 - val_accuracy: 0.8751
# Epoch 15/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3530 - accuracy: 0.8666 - val_loss: 0.3285 - val_accuracy: 0.8744
# Epoch 16/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3481 - accuracy: 0.8693 - val_loss: 0.3296 - val_accuracy: 0.8744
# Epoch 17/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3464 - accuracy: 0.8688 - val_loss: 0.3298 - val_accuracy: 0.8731
# Epoch 18/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3385 - accuracy: 0.8715 - val_loss: 0.3261 - val_accuracy: 0.8755
# Epoch 19/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3389 - accuracy: 0.8715 - val_loss: 0.3229 - val_accuracy: 0.8783
# Epoch 20/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3359 - accuracy: 0.8734 - val_loss: 0.3187 - val_accuracy: 0.8790
# Epoch 21/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3323 - accuracy: 0.8739 - val_loss: 0.3235 - val_accuracy: 0.8760
# ./Results/Fold_5/Models/20241208-2003
# Epoch 1/200
# 145/145 [==============================] - 46s 134ms/step - loss: 0.7836 - accuracy: 0.7099 - val_loss: 0.5057 - val_accuracy: 0.8062
# Epoch 2/200
# 145/145 [==============================] - 9s 64ms/step - loss: 0.5445 - accuracy: 0.7988 - val_loss: 0.4677 - val_accuracy: 0.8194
# Epoch 3/200
# 145/145 [==============================] - 9s 64ms/step - loss: 0.4919 - accuracy: 0.8134 - val_loss: 0.4252 - val_accuracy: 0.8317
# Epoch 4/200
# 145/145 [==============================] - 8s 52ms/step - loss: 0.4641 - accuracy: 0.8232 - val_loss: 0.4023 - val_accuracy: 0.8409
# Epoch 5/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.4494 - accuracy: 0.8282 - val_loss: 0.3911 - val_accuracy: 0.8483
# Epoch 6/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.4334 - accuracy: 0.8350 - val_loss: 0.3865 - val_accuracy: 0.8454
# Epoch 7/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.4124 - accuracy: 0.8425 - val_loss: 0.3649 - val_accuracy: 0.8541
# Epoch 8/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.4049 - accuracy: 0.8461 - val_loss: 0.3651 - val_accuracy: 0.8565
# Epoch 9/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3899 - accuracy: 0.8509 - val_loss: 0.3540 - val_accuracy: 0.8605
# Epoch 10/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3834 - accuracy: 0.8539 - val_loss: 0.3539 - val_accuracy: 0.8596
# Epoch 11/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3755 - accuracy: 0.8557 - val_loss: 0.3467 - val_accuracy: 0.8640
# Epoch 12/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3700 - accuracy: 0.8604 - val_loss: 0.3459 - val_accuracy: 0.8628
# Epoch 13/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3644 - accuracy: 0.8627 - val_loss: 0.3431 - val_accuracy: 0.8644
# Epoch 14/200
# 145/145 [==============================] - 7s 51ms/step - loss: 0.3581 - accuracy: 0.8648 - val_loss: 0.3366 - val_accuracy: 0.8688
# Epoch 15/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3547 - accuracy: 0.8658 - val_loss: 0.3350 - val_accuracy: 0.8702
# Epoch 16/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3486 - accuracy: 0.8682 - val_loss: 0.3403 - val_accuracy: 0.8651
# Epoch 17/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3456 - accuracy: 0.8712 - val_loss: 0.3331 - val_accuracy: 0.8676
# Epoch 18/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3388 - accuracy: 0.8719 - val_loss: 0.3322 - val_accuracy: 0.8696
# Epoch 19/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3403 - accuracy: 0.8721 - val_loss: 0.3329 - val_accuracy: 0.8696
# Epoch 20/200
# 145/145 [==============================] - 9s 60ms/step - loss: 0.3330 - accuracy: 0.8733 - val_loss: 0.3309 - val_accuracy: 0.8702
# Epoch 21/200
# 145/145 [==============================] - 8s 54ms/step - loss: 0.3362 - accuracy: 0.8748 - val_loss: 0.3286 - val_accuracy: 0.8696
# ./Results/Fold_6/Models/20241208-2006
# Epoch 1/200
# 145/145 [==============================] - 48s 117ms/step - loss: 0.7554 - accuracy: 0.7200 - val_loss: 0.4974 - val_accuracy: 0.8140
# Epoch 2/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.5333 - accuracy: 0.8020 - val_loss: 0.4627 - val_accuracy: 0.8201
# Epoch 3/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4835 - accuracy: 0.8178 - val_loss: 0.4285 - val_accuracy: 0.8333
# Epoch 4/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4545 - accuracy: 0.8271 - val_loss: 0.3982 - val_accuracy: 0.8461
# Epoch 5/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4416 - accuracy: 0.8326 - val_loss: 0.4038 - val_accuracy: 0.8457
# Epoch 6/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4198 - accuracy: 0.8399 - val_loss: 0.3782 - val_accuracy: 0.8540
# Epoch 7/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4138 - accuracy: 0.8445 - val_loss: 0.3738 - val_accuracy: 0.8545
# Epoch 8/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4011 - accuracy: 0.8467 - val_loss: 0.3546 - val_accuracy: 0.8639
# Epoch 9/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3905 - accuracy: 0.8531 - val_loss: 0.3472 - val_accuracy: 0.8684
# Epoch 10/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3829 - accuracy: 0.8571 - val_loss: 0.3479 - val_accuracy: 0.8665
# Epoch 11/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3745 - accuracy: 0.8582 - val_loss: 0.3409 - val_accuracy: 0.8693
# Epoch 12/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3646 - accuracy: 0.8601 - val_loss: 0.3409 - val_accuracy: 0.8696
# Epoch 13/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3583 - accuracy: 0.8633 - val_loss: 0.3371 - val_accuracy: 0.8724
# Epoch 14/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3565 - accuracy: 0.8643 - val_loss: 0.3345 - val_accuracy: 0.8726
# Epoch 15/200
# 145/145 [==============================] - 7s 51ms/step - loss: 0.3520 - accuracy: 0.8675 - val_loss: 0.3267 - val_accuracy: 0.8756
# Epoch 16/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3437 - accuracy: 0.8693 - val_loss: 0.3361 - val_accuracy: 0.8694
# Epoch 17/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3441 - accuracy: 0.8704 - val_loss: 0.3260 - val_accuracy: 0.8747
# Epoch 18/200
# 145/145 [==============================] - 9s 62ms/step - loss: 0.3386 - accuracy: 0.8723 - val_loss: 0.3263 - val_accuracy: 0.8739
# Epoch 19/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3366 - accuracy: 0.8726 - val_loss: 0.3235 - val_accuracy: 0.8757
# Epoch 20/200
# 145/145 [==============================] - 7s 49ms/step - loss: 0.3334 - accuracy: 0.8748 - val_loss: 0.3250 - val_accuracy: 0.8751
# Epoch 21/200
# 145/145 [==============================] - 8s 57ms/step - loss: 0.3322 - accuracy: 0.8744 - val_loss: 0.3244 - val_accuracy: 0.8774
# ./Results/Fold_7/Models/20241208-2010
# Epoch 1/200
# 145/145 [==============================] - 40s 91ms/step - loss: 0.8007 - accuracy: 0.7095 - val_loss: 0.5057 - val_accuracy: 0.8170
# Epoch 2/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.5442 - accuracy: 0.7986 - val_loss: 0.4512 - val_accuracy: 0.8333
# Epoch 3/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.4961 - accuracy: 0.8142 - val_loss: 0.4170 - val_accuracy: 0.8406
# Epoch 4/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.4631 - accuracy: 0.8252 - val_loss: 0.3853 - val_accuracy: 0.8500
# Epoch 5/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.4444 - accuracy: 0.8299 - val_loss: 0.3871 - val_accuracy: 0.8480
# Epoch 6/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4318 - accuracy: 0.8368 - val_loss: 0.3640 - val_accuracy: 0.8559
# Epoch 7/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.4161 - accuracy: 0.8416 - val_loss: 0.3641 - val_accuracy: 0.8567
# Epoch 8/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.4072 - accuracy: 0.8447 - val_loss: 0.3469 - val_accuracy: 0.8648
# Epoch 9/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3955 - accuracy: 0.8502 - val_loss: 0.3459 - val_accuracy: 0.8631
# Epoch 10/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.3886 - accuracy: 0.8518 - val_loss: 0.3376 - val_accuracy: 0.8693
# Epoch 11/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.3807 - accuracy: 0.8553 - val_loss: 0.3302 - val_accuracy: 0.8696
# Epoch 12/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3732 - accuracy: 0.8584 - val_loss: 0.3285 - val_accuracy: 0.8722
# Epoch 13/200
# 145/145 [==============================] - 7s 50ms/step - loss: 0.3656 - accuracy: 0.8612 - val_loss: 0.3225 - val_accuracy: 0.8725
# Epoch 14/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3640 - accuracy: 0.8619 - val_loss: 0.3212 - val_accuracy: 0.8743
# Epoch 15/200
# 145/145 [==============================] - 9s 65ms/step - loss: 0.3609 - accuracy: 0.8626 - val_loss: 0.3213 - val_accuracy: 0.8770
# Epoch 16/200
# 145/145 [==============================] - 7s 48ms/step - loss: 0.3543 - accuracy: 0.8658 - val_loss: 0.3206 - val_accuracy: 0.8738
# Epoch 17/200
# 145/145 [==============================] - 7s 47ms/step - loss: 0.3499 - accuracy: 0.8672 - val_loss: 0.3162 - val_accuracy: 0.8755
# Epoch 18/200
# 145/145 [==============================] - 8s 53ms/step - loss: 0.3487 - accuracy: 0.8679 - val_loss: 0.3120 - val_accuracy: 0.8783
# Epoch 19/200
# 145/145 [==============================] - 10s 65ms/step - loss: 0.3445 - accuracy: 0.8683 - val_loss: 0.3104 - val_accuracy: 0.8796
# Epoch 20/200
# 145/145 [==============================] - 9s 60ms/step - loss: 0.3389 - accuracy: 0.8717 - val_loss: 0.3093 - val_accuracy: 0.8776
# Epoch 21/200
# 145/145 [==============================] - 10s 67ms/step - loss: 0.3378 - accuracy: 0.8721 - val_loss: 0.3089 - val_accuracy: 0.8786

# %%
1
