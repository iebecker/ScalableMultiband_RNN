# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from glob import glob
from itertools import combinations
sys.path.append('/home/ibecker/Dropbox/MyPythonClasses/FinalClass/')

import Classifier.Model_53.Multiband_53 as multiband
from Classifier.Model_53.CustomLayers import SauceLayer, LastRelevantLayer, ApplyMask, MeanMagLayer, MeanColorLayer

# %% [markdown]
# Classifier mode only should ignore physical parameters listed in the input.

# %%
# To see if the system regognises the GPU
device = 0
devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.set_visible_devices(devices[device], 'GPU')
tf.config.experimental.set_memory_growth(device=devices[device], enable=True)

# %% [markdown]
# Find the different folds and train a model using the stored data.

# %%
survey = 'PanStarrs'
path = os.path.join('../../02_Create_Records/', survey, 'Folds/Fold_*',)
folds = glob(path)
folds.sort()
folds
# Out:
# ['../../02_Create_Records/PanStarrs/Folds/Fold_1',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_2',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_3',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_4',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_5',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_6',
#  '../../02_Create_Records/PanStarrs/Folds/Fold_7']

# %% [markdown]
# Create folder results

# %%
if not os.path.exists('./Results'):
    os.mkdir('./Results')

# %% [markdown]
# Define the arguments for all the models.

# %%
train_args = {
            'hidden_size_bands':[64, 64, 64],
            'hidden_size_central':[64, 64, 64],
            'fc_layers_bands':[128,128],
            'fc_layers_central':[128,128], # Neurons of each layer
            'regression_size':[128, 128],#each element is a layer with that size.
            'buffer_size':10000,
            'epochs':1000,
            'num_threads':7,
            'batch_size':512,
            'dropout':0.35,
            'lr':[[5e-3]*5, 2.5e-3], # [[band1, band2], central]
            'val_steps':50,
            'max_to_keep':0, # Not Used 
            'steps_wait':500, 
            'use_class_weights':False,# Not Used
            'mode' : 'classifier'
            }
loss_weights = {'Class':1.0}

callbacks_args = {'patience': 20,
                  'mode':'max',
                  'restore_best_weights':True,
                  'min_delta': 0.001
                 }
train_args_specific={
                    'phys_params': [],
                    'use_output_bands' : True,  # Working
                    'use_output_central' : False, # Not used
                    'use_common_layers' : False, # NOT Working
                    'bidirectional_central' : False,# Working
                    'bidirectional_band' : False,# Not Working
                    'layer_norm_params' : None, # Used to normalyze common layers
                    'use_gated_common' : False, # Working
                    'l1':0.0,
                    'l2':0.0,
                    'N_skip' : 2, # Cannot be greater than the number of timesteps
                    'use_raw_input_central': False,
                    'train_steps_central' : 1,
                    'print_report' : True,
                    'loss_weights_central' : loss_weights,
                    'callbacks_args':callbacks_args    
                    }

# %%
def compute_FinalMeanMags(output, length):

    batch_size = tf.shape(output)[0]
    indices = tf.stack([tf.range(0, batch_size), length], axis=1)
    final_MeanMags = tf.gather_nd(output, indices)
    return final_MeanMags

def compute_ColorMatrix(n_bands):
    ''' Obtains the matrix to compute the colors (magnitude differences)
    between all the bands. In the 2-band scenario it reduces to [[1, -1]].
    '''
    NN = n_bands
    # Compute all possible combinations
    combs = set(combinations(np.arange(NN),2))
    combs = [list(i) for i in combs]
    combs = tf.constant(combs)

    # Compute the index of the first elements
    v1 = tf.reshape(combs[:,0],[-1,1])
    v1b =tf.reshape(tf.range(tf.shape(combs)[0]), [-1,1])
    v1 = tf.concat([v1b, v1], axis=1)
    # Compute the index of the second elements
    v2 = tf.reshape(combs[:,1],[-1,1])
    v1b =tf.reshape(tf.range(tf.shape(combs)[0]), [-1,1])
    v2 = tf.concat([v1b, v2], axis=1)

    # Concatenate and cast to int64
    indices= tf.concat([v1, v2], axis=0)
    indices = tf.cast(indices, tf.int64)

    # First part are the first elements
    u1 = tf.ones(tf.shape(v1)[0])
    # Second part are the subtracted elements
    u2 = -tf.ones(tf.shape(v1)[0])
    updates= tf.concat([u1,u2], axis=0)

    # Compute the shape #combinations x bands
    shape = tf.concat([tf.shape(v1)[0], NN], axis=0)
    shape = tf.cast(shape, tf.int64)

    # Obtain the matrix
    diff_matrix = tf.scatter_nd(indices, updates, shape)

    # Transpose it to perform MatMult afterwards
    diff_matrix = tf.transpose(diff_matrix)
    return diff_matrix

# %%
class LastRelevantLayer_mod(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(LastRelevantLayer_mod, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, output, length):
        '''Get the last relevant output from the network'''
        batch_size = tf.shape(output)[0]
        max_length = tf.shape(output)[1]
        out_size = tf.shape(output)[2]

        index = tf.range(0, batch_size) * max_length + (length - 1)
        flat = tf.reshape(output, [-1, out_size])
        relevant = tf.gather(flat, index)
        
        relevant = tf.reshape(relevant, [batch_size, output.shape[2]])
        return relevant
 

def creat_split_models():
    tf.keras.backend.clear_session()
    inputs = {}
    keys =new.dataset_test.element_spec[0].keys()
    for key in keys:
        inputs[key] = tf.keras.layers.Input(shape=new.dataset_test.element_spec[0][key].shape[1:],
                                            dtype=new.dataset_test.element_spec[0][key].dtype,
                                            name=key
                                            )
    out = {}
    sauces = []
    Mean_Mags = []
    
    for model in range(len(new.models)):
        # Get the single band outputs
        new.models[model].trainable = True
        out[model] = new.models[model].layers[2].output
        slice_model = tf.keras.Model(inputs=new.models[model].inputs, outputs=out[model])

        out_model = slice_model(inputs)
        # Get the last relevant per band per output
        lasts = []
        for i in range(len(out_model)):
            last_relevant = LastRelevantLayer_mod()(out_model[i], inputs['N_'+str(model)])
            lasts.append(last_relevant)
        # Create a Sauce layer per band
        size = len(lasts)
        sauce = SauceLayer(size, name='Sauce_'+str(model))(lasts)
        sauces.append(sauce)

        # Compute the mean mags
        MeanMag = MeanMagLayer(new.w,
                               name='MeanMag_'+str(model)
                               )
        mean_mags = MeanMag(inputs['input_LC_'+str(model)],
                            inputs['N_'+str(model)],
                            inputs['M0_'+str(model)],
                            )        
        Mean_Mags.append(mean_mags)

    final_MeanMags = [compute_FinalMeanMags(Mean_Mags[i], inputs['N_'+str(i)]) for i in range(new.n_bands)]
    final_MeanMags = tf.stack(final_MeanMags, axis=1)
    color_matrix = compute_ColorMatrix(new.n_bands)
    colors = tf.matmul(final_MeanMags, color_matrix)
        
    # Stack the outputs
    embedding = tf.keras.layers.Concatenate(axis=1, name='Concat_Sauces')(sauces)

    # Stack the colors
    embedding =  tf.keras.layers.Concatenate(axis=-1, name='Concat_Colors')([embedding, colors])
    # Add dense layers with dropout
    sizes = train_args['fc_layers_central']
    proyections = embedding
    for b in range(len(sizes)):
        proyections = tf.keras.layers.Dense(sizes[b],
                                        activation=None,
                                        use_bias=False,
                                        )(proyections)
        proyections = tf.keras.layers.BatchNormalization()(proyections, training=True)
        proyections = tf.keras.activations.relu(proyections)

        proyections = tf.keras.layers.Dropout(new.dropout)(proyections)

    predictions_prob = tf.keras.layers.Dense(new.num_classes,
                                             activation='softmax',
                                             use_bias=True,
                                             name='Predictions',
    #                                          bias_initializer=tf.constant_initializer(1.0/self.numpy_weights),
                                             )(proyections)
    outputs = {
            'Class': predictions_prob,

            }
    model = tf.keras.Model(inputs = inputs, outputs=outputs)
    optimizer = new.optimizers[0]
    loss = 'categorical_crossentropy'
    model.compile(optimizer=optimizer, loss=loss, metrics='accuracy')

    return model

# %%
sauces = []
for fold in folds:
    tf.keras.backend.clear_session()
    # Set the fold path
    base_dir = fold+'/'
    
    # Set the save path for this fold. Create folder if needed
    path_results_fold = fold.replace('../../02_Create_Records/'+survey+'/', './').replace('/Folds/', '/Results/')
    if not os.path.exists(path_results_fold):
        os.mkdir(path_results_fold)    
        
    train_args_specific['save_dir'] = path_results_fold
    train_args_specific['metadata_pre_path'] = base_dir+'metadata_preprocess.json'  
    train_args_specific['path_scalers'] =  base_dir+'scalers.pkl'
    # Define the train args
    train_args = {**train_args, **train_args_specific}
    
    train_files = base_dir+'train/*.tfrecord'
    val_files = base_dir+'val/*.tfrecord'
    test_files = base_dir+'test/*.tfrecord'
    
    new = multiband.Network()    
    new.train(train_args, train_files, val_files, test_files)
    model = creat_split_models()
    
    es = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',**callbacks_args)
    model.fit(new.dataset_train, validation_data=new.dataset_val, epochs=200,callbacks = [es] )
    
    # Store the alpha coefficients per fold
    sauces_ = {i.name:i for i in model.layers if 'Sauce_' in i.name}
    scales = {key:tf.nn.softmax(sauces_[key].scale).numpy() for key in sauces_.keys()}
    sauces.append(scales)
    # Test
    dfs = []
    for batch in new.dataset_test:
        prediction = model(batch[0])
        y_pred = prediction['Class'].numpy().argmax(axis=1)
        y_pred = [new.trans[i] for i in y_pred]
        ID = batch[0]['ID'].numpy()

        y_true = batch[1]['Class'].numpy().argmax(axis=1)
        y_true = [new.trans[i] for i in y_true]

        df = pd.DataFrame(np.array([ID, y_pred, y_true]).transpose(), columns=['ID', 'Class', 'Pred'])
        df.ID = df.ID.str.decode('UTF-8')
        dfs.append(df)
    dfs = pd.concat(dfs, axis=0)
    dfs.to_csv(path_results_fold+'/Classification_test.dat', index=False, index_label=False)
    
pd.DataFrame(sauces).to_csv(path_results_fold+'/sauces.dat', index=False, index_label=False)
# Out:
# ./Results/Fold_1/Models/20230309-0940
# Epoch 1/200
# 52/52 [==============================] - 53s 317ms/step - loss: 0.9569 - accuracy: 0.6061 - val_loss: 0.7294 - val_accuracy: 0.6936
# Epoch 2/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0
200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.3170 - accuracy: 0.8835 - val_loss: 0.4428 - val_accuracy: 0.8424
# Epoch 15/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.2883 - accuracy: 0.8959 - val_loss: 0.4657 - val_accuracy: 0.8351
# Epoch 16/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2741 - accuracy: 0.9011 - val_loss: 0.4648 - val_accuracy: 0.8404
# Epoch 17/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2500 - accuracy: 0.9115 - val_loss: 0.5039 - val_accuracy: 0.8331
# Epoch 18/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2357 - accuracy: 0.9180 - val_loss: 0.5132 - val_accuracy: 0.8340
# Epoch 19/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2109 - accuracy: 0.9287 - val_loss: 0.5507 - val_accuracy: 0.8303
# Epoch 20/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1827 - accuracy: 0.9391 - val_loss: 0.5831 - val_accuracy: 0.8301
# Epoch 21/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1654 - accuracy: 0.9451 - val_loss: 0.6057 - val_accuracy: 0.8290
# Epoch 22/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1552 - accuracy: 0.9472 - val_loss: 0.6368 - val_accuracy: 0.8283
# Epoch 23/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1388 - accuracy: 0.9545 - val_loss: 0.6641 - val_accuracy: 0.8326
# Epoch 24/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1198 - accuracy: 0.9619 - val_loss: 0.6976 - val_accuracy: 0.8244
# Epoch 25/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1149 - accuracy: 0.9621 - val_loss: 0.7313 - val_accuracy: 0.8239
# Epoch 26/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1054 - accuracy: 0.9658 - val_loss: 0.7262 - val_accuracy: 0.8273
# Epoch 27/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0924 - accuracy: 0.9703 - val_loss: 0.8165 - val_accuracy: 0.8219
# Epoch 28/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0860 - accuracy: 0.9721 - val_loss: 0.8223 - val_accuracy: 0.8228
# Epoch 29/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0743 - accuracy: 0.9745 - val_loss: 0.8518 - val_accuracy: 0.8203
# Epoch 30/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0648 - accuracy: 0.9784 - val_loss: 0.8605 - val_accuracy: 0.8269
# Epoch 31/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0600 - accuracy: 0.9808 - val_loss: 0.8973 - val_accuracy: 0.8216
# Epoch 32/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0638 - accuracy: 0.9793 - val_loss: 0.9494 - val_accuracy: 0.8212
# Epoch 33/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0533 - accuracy: 0.9838 - val_loss: 0.9420 - val_accuracy: 0.8205
# Epoch 34/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0475 - accuracy: 0.9853 - val_loss: 0.9484 - val_accuracy: 0.8152
# ./Results/Fold_5/Models/20230309-0954
# Epoch 1/200
# 52/52 [==============================] - 54s 318ms/step - loss: 0.9263 - accuracy: 0.6114 - val_loss: 0.7216 - val_accuracy: 0.6840
# Epoch 2/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.7087 - accuracy: 0.6979 - val_loss: 0.6495 - val_accuracy: 0.7254
# Epoch 3/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.6362 - accuracy: 0.7330 - val_loss: 0.5783 - val_accuracy: 0.7599
# Epoch 4/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.5720 - accuracy: 0.7655 - val_loss: 0.5433 - val_accuracy: 0.7823
# Epoch 5/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.5228 - accuracy: 0.7889 - val_loss: 0.5086 - val_accuracy: 0.7949
# Epoch 6/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.4985 - accuracy: 0.7998 - val_loss: 0.4928 - val_accuracy: 0.8065
# Epoch 7/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.4723 - accuracy: 0.8123 - val_loss: 0.4736 - val_accuracy: 0.8095
# Epoch 8/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.4440 - accuracy: 0.8255 - val_loss: 0.4617 - val_accuracy: 0.8198
# Epoch 9/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.4265 - accuracy: 0.8352 - val_loss: 0.4670 - val_accuracy: 0.8196
# Epoch 10/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3968 - accuracy: 0.8469 - val_loss: 0.4634 - val_accuracy: 0.8230
# Epoch 11/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3733 - accuracy: 0.8583 - val_loss: 0.4503 - val_accuracy: 0.8257
# Epoch 12/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3506 - accuracy: 0.8694 - val_loss: 0.4624 - val_accuracy: 0.8290
# Epoch 13/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.3324 - accuracy: 0.8784 - val_loss: 0.4669 - val_accuracy: 0.8283
# Epoch 14/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3136 - accuracy: 0.8849 - val_loss: 0.4737 - val_accuracy: 0.8317
# Epoch 15/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2868 - accuracy: 0.8954 - val_loss: 0.4958 - val_accuracy: 0.8326
# Epoch 16/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2640 - accuracy: 0.9055 - val_loss: 0.5152 - val_accuracy: 0.8312
# Epoch 17/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2498 - accuracy: 0.9102 - val_loss: 0.5204 - val_accuracy: 0.8303
# Epoch 18/200
# 52/52 [==============================] - 4s 82ms/step - loss: 0.2240 - accuracy: 0.9218 - val_loss: 0.5651 - val_accuracy: 0.8214
# Epoch 19/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2004 - accuracy: 0.9309 - val_loss: 0.5634 - val_accuracy: 0.8301
# Epoch 20/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1914 - accuracy: 0.9349 - val_loss: 0.6008 - val_accuracy: 0.8209
# Epoch 21/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1666 - accuracy: 0.9450 - val_loss: 0.6280 - val_accuracy: 0.8278
# Epoch 22/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1531 - accuracy: 0.9477 - val_loss: 0.6730 - val_accuracy: 0.8173
# Epoch 23/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1405 - accuracy: 0.9536 - val_loss: 0.6762 - val_accuracy: 0.8225
# Epoch 24/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1506 - accuracy: 0.9506 - val_loss: 0.6950 - val_accuracy: 0.8205
# Epoch 25/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1203 - accuracy: 0.9623 - val_loss: 0.7451 - val_accuracy: 0.8225
# Epoch 26/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1069 - accuracy: 0.9656 - val_loss: 0.7588 - val_accuracy: 0.8241
# Epoch 27/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0994 - accuracy: 0.9680 - val_loss: 0.7872 - val_accuracy: 0.8230
# Epoch 28/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0847 - accuracy: 0.9734 - val_loss: 0.8279 - val_accuracy: 0.8225
# Epoch 29/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.8665 - val_accuracy: 0.8148
# Epoch 30/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0782 - accuracy: 0.9757 - val_loss: 0.9069 - val_accuracy: 0.8200
# Epoch 31/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0706 - accuracy: 0.9772 - val_loss: 0.8794 - val_accuracy: 0.8232
# Epoch 32/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.0605 - accuracy: 0.9829 - val_loss: 0.9278 - val_accuracy: 0.8182
# Epoch 33/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0552 - accuracy: 0.9828 - val_loss: 0.9563 - val_accuracy: 0.8152
# Epoch 34/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0586 - accuracy: 0.9815 - val_loss: 0.9689 - val_accuracy: 0.8241
# ./Results/Fold_6/Models/20230309-0958
# Epoch 1/200
# 52/52 [==============================] - 54s 308ms/step - loss: 0.9507 - accuracy: 0.6018 - val_loss: 0.7339 - val_accuracy: 0.6840
# Epoch 2/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.7129 - accuracy: 0.7009 - val_loss: 0.6328 - val_accuracy: 0.7304
# Epoch 3/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.6112 - accuracy: 0.7466 - val_loss: 0.5849 - val_accuracy: 0.7597
# Epoch 4/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.5474 - accuracy: 0.7781 - val_loss: 0.5060 - val_accuracy: 0.7956
# Epoch 5/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.5143 - accuracy: 0.7965 - val_loss: 0.4830 - val_accuracy: 0.8011
# Epoch 6/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.4848 - accuracy: 0.8106 - val_loss: 0.4686 - val_accuracy: 0.8040
# Epoch 7/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.4594 - accuracy: 0.8213 - val_loss: 0.4748 - val_accuracy: 0.8116
# Epoch 8/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.4342 - accuracy: 0.8329 - val_loss: 0.4570 - val_accuracy: 0.8161
# Epoch 9/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.4096 - accuracy: 0.8443 - val_loss: 0.4548 - val_accuracy: 0.8235
# Epoch 10/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3958 - accuracy: 0.8513 - val_loss: 0.4361 - val_accuracy: 0.8317
# Epoch 11/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3676 - accuracy: 0.8619 - val_loss: 0.4432 - val_accuracy: 0.8239
# Epoch 12/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3472 - accuracy: 0.8716 - val_loss: 0.4570 - val_accuracy: 0.8264
# Epoch 13/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3317 - accuracy: 0.8799 - val_loss: 0.4616 - val_accuracy: 0.8273
# Epoch 14/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.3093 - accuracy: 0.8871 - val_loss: 0.4719 - val_accuracy: 0.8324
# Epoch 15/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2837 - accuracy: 0.8985 - val_loss: 0.4977 - val_accuracy: 0.8276
# Epoch 16/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2681 - accuracy: 0.9052 - val_loss: 0.5030 - val_accuracy: 0.8312
# Epoch 17/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.2504 - accuracy: 0.9120 - val_loss: 0.5214 - val_accuracy: 0.8262
# Epoch 18/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.2232 - accuracy: 0.9228 - val_loss: 0.5559 - val_accuracy: 0.8262
# Epoch 19/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.1978 - accuracy: 0.9316 - val_loss: 0.5755 - val_accuracy: 0.8212
# Epoch 20/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.1809 - accuracy: 0.9369 - val_loss: 0.5906 - val_accuracy: 0.8264
# Epoch 21/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1744 - accuracy: 0.9405 - val_loss: 0.6133 - val_accuracy: 0.8257
# Epoch 22/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1559 - accuracy: 0.9476 - val_loss: 0.6666 - val_accuracy: 0.8205
# Epoch 23/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1443 - accuracy: 0.9515 - val_loss: 0.6724 - val_accuracy: 0.8257
# Epoch 24/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1301 - accuracy: 0.9557 - val_loss: 0.7365 - val_accuracy: 0.8152
# Epoch 25/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.1203 - accuracy: 0.9607 - val_loss: 0.7516 - val_accuracy: 0.8173
# Epoch 26/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.1032 - accuracy: 0.9657 - val_loss: 0.7958 - val_accuracy: 0.8180
# Epoch 27/200
# 52/52 [==============================] - 4s 77ms/step - loss: 0.0931 - accuracy: 0.9699 - val_loss: 0.8255 - val_accuracy: 0.8203
# Epoch 28/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.0867 - accuracy: 0.9715 - val_loss: 0.8230 - val_accuracy: 0.8134
# Epoch 29/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0784 - accuracy: 0.9739 - val_loss: 0.8653 - val_accuracy: 0.8132
# Epoch 30/200
# 52/52 [==============================] - 4s 79ms/step - loss: 0.0667 - accuracy: 0.9787 - val_loss: 0.8918 - val_accuracy: 0.8155
# ./Results/Fold_7/Models/20230309-1001
# Epoch 1/200
# 52/52 [==============================] - 55s 327ms/step - loss: 0.9272 - accuracy: 0.6056 - val_loss: 0.7049 - val_accuracy: 0.6970
# Epoch 2/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.7121 - accuracy: 0.7026 - val_loss: 0.6449 - val_accuracy: 0.7167
# Epoch 3/200
# 52/52 [==============================] - 4s 75ms/step - loss: 0.6318 - accuracy: 0.7408 - val_loss: 0.5935 - val_accuracy: 0.7469
# Epoch 4/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.5655 - accuracy: 0.7696 - val_loss: 0.5354 - val_accuracy: 0.7750
# Epoch 5/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.5289 - accuracy: 0.7868 - val_loss: 0.5225 - val_accuracy: 0.7857
# Epoch 6/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.4864 - accuracy: 0.8087 - val_loss: 0.4900 - val_accuracy: 0.7942
# Epoch 7/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.4592 - accuracy: 0.8200 - val_loss: 0.4857 - val_accuracy: 0.8068
# Epoch 8/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.4414 - accuracy: 0.8293 - val_loss: 0.4827 - val_accuracy: 0.7988
# Epoch 9/200
# 52/52 [==============================] - 4s 78ms/step - loss: 0.4128 - accuracy: 0.8400 - val_loss: 0.4925 - val_accuracy: 0.8033
# Epoch 10/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.4038 - accuracy: 0.8472 - val_loss: 0.4653 - val_accuracy: 0.8228
# Epoch 11/200
# 52/52 [==============================] - 4s 74ms/step - loss: 0.3706 - accuracy: 0.8610 - val_loss: 0.4514 - val_accuracy: 0.8269
# Epoch 12/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.3484 - accuracy: 0.8698 - val_loss: 0.4589 - val_accuracy: 0.8278
# Epoch 13/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.3275 - accuracy: 0.8782 - val_loss: 0.4664 - val_accuracy: 0.8248
# Epoch 14/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.3108 - accuracy: 0.8875 - val_loss: 0.4843 - val_accuracy: 0.8244
# Epoch 15/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.2865 - accuracy: 0.8958 - val_loss: 0.5157 - val_accuracy: 0.8164
# Epoch 16/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.2673 - accuracy: 0.9043 - val_loss: 0.5096 - val_accuracy: 0.8221
# Epoch 17/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.2463 - accuracy: 0.9121 - val_loss: 0.5339 - val_accuracy: 0.8193
# Epoch 18/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.2259 - accuracy: 0.9231 - val_loss: 0.5560 - val_accuracy: 0.8219
# Epoch 19/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1995 - accuracy: 0.9314 - val_loss: 0.6005 - val_accuracy: 0.8214
# Epoch 20/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1847 - accuracy: 0.9370 - val_loss: 0.6208 - val_accuracy: 0.8177
# Epoch 21/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1723 - accuracy: 0.9415 - val_loss: 0.6377 - val_accuracy: 0.8173
# Epoch 22/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1470 - accuracy: 0.9515 - val_loss: 0.6939 - val_accuracy: 0.8209
# Epoch 23/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1382 - accuracy: 0.9542 - val_loss: 0.7026 - val_accuracy: 0.8189
# Epoch 24/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.1186 - accuracy: 0.9616 - val_loss: 0.7498 - val_accuracy: 0.8152
# Epoch 25/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.1091 - accuracy: 0.9641 - val_loss: 0.7732 - val_accuracy: 0.8203
# Epoch 26/200
# 52/52 [==============================] - 4s 71ms/step - loss: 0.1041 - accuracy: 0.9654 - val_loss: 0.8306 - val_accuracy: 0.8127
# Epoch 27/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0894 - accuracy: 0.9708 - val_loss: 0.8553 - val_accuracy: 0.8155
# Epoch 28/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0773 - accuracy: 0.9756 - val_loss: 0.8827 - val_accuracy: 0.8155
# Epoch 29/200
# 52/52 [==============================] - 4s 72ms/step - loss: 0.0771 - accuracy: 0.9753 - val_loss: 0.8829 - val_accuracy: 0.8200
# Epoch 30/200
# 52/52 [==============================] - 4s 73ms/step - loss: 0.0668 - accuracy: 0.9792 - val_loss: 0.9480 - val_accuracy: 0.8157
# Epoch 31/200
# 52/52 [==============================] - 4s 76ms/step - loss: 0.0602 - accuracy: 0.9817 - val_loss: 0.9722 - val_accuracy: 0.8155

# %%
1
# Out:
# 1
